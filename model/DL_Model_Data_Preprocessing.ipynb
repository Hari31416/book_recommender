# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tqdm.auto import tqdm
from scipy import sparse
import torch

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data

# %% [markdown]
# ## Load data

# %%
DATA_DIR = os.path.join("..", "data", "final_dataset")

# %%
interactions = pd.read_parquet(os.path.join(DATA_DIR, 'ratings.parquet'))
books= pd.read_parquet(os.path.join(DATA_DIR, 'books_all.parquet'))
users = pd.read_parquet(os.path.join(DATA_DIR, 'users.parquet'))
interactions = interactions[interactions["isbn"].isin(books["isbn"])]
interactions = interactions.query("provided_rating!=0")
interactions.reset_index(drop=True, inplace=True)
print(f"Number of ratings: {len(interactions)}")
print(f"Number of unique users: {interactions['user_id'].nunique()}")
print(f"Number of books: {interactions['isbn'].nunique()}")
print(f"Shape of interactions: {interactions.shape}")
print(f"Shape of books: {books.shape}")
print(f"Shape of users: {users.shape}")
interactions.head()
# Out:
# Number of ratings: 104756
# Number of unique users: 31940
# Number of books: 22020
# Shape of interactions: (104756, 3)
# Shape of books: (215397, 18)
# Shape of users: (278858, 3)
#    user_id        isbn  provided_rating
# 0       17  0891075275                6
# 1       17  0553264990                5
# 2       26  0449005615                9
# 3       39  0671888587                7
# 4       69  1853260053                8

# %% [markdown]
# We will remove the extra users and books that are not in the interaction.

# %%
user_ids = interactions["user_id"].unique().tolist()
isbns = interactions["isbn"].unique().tolist()
users = users.query(f"user_id in {user_ids}")
books = books.query(f"isbn in {isbns}")
print(f"Shape of books: {books.shape}")
print(f"Shape of users: {users.shape}")
# Out:
# Shape of books: (22058, 18)
# Shape of users: (31940, 3)

# %% [markdown]
# We have left with a very few books and users.

# %%
books.head()
# Out:
#     num_pages  star_rating_1  star_rating_2  star_rating_3  star_rating_4  \
# 1         870          12455          37005         211781         604283
# 3         352          11896          49353         288821         706082
# 4         435          10128          24849         194848         630534
# 8         815           3443           7613          30030          75683
# 11         55            249            985           3342           2409
#
#     star_rating_5  average_rating  total_ratings  total_reviews        isbn  \
# 1         1493113            4.50        2358637          29770  0439358078
# 3         1504505            4.42        2560657            244  0439554896
# 4         1749958            4.57        2610317          37093  043965548X
# 8          157499            4.37         274268           4119  0345453743
# 11           1408            3.45           8393            503  0767915062
#
#    publication_date                                          title  \
# 1        2004-09-01      Harry Potter and the Order of the Phoenix
# 3        2003-11-01        Harry Potter and the Chamber of Secrets
# 4        2004-05-01       Harry Potter and the Prisoner of Azkaban
# 8        2002-04-30  The Ultimate Hitchhiker's Guide to the Galaxy
# 11       2002-12-03                    Bill Bryson's African Diary
#
#                               series  book_number_in_series          authors  \
# 1                       Harry Potter                      5   [J.K. Rowling]
# 3                       Harry Potter                      2   [J.K. Rowling]
# 4                       Harry Potter                      3   [J.K. Rowling]
# 8   Hitchhiker's Guide to the Galaxy                      5  [Douglas Adams]
# 11                        Standalone                      1    [Bill Bryson]
#
#                                            categories format lang
# 1    [Fantasy, Fantasy Books, Fantasy Books for Kids]     CD   en
# 3    [Fantasy, Fantasy Books, Fantasy Books for Kids]     CD   en
# 4    [Fantasy, Fantasy Books, Fantasy Books for Kids]     CD   en
# 8   [Contemporary Fiction, Science Fiction, Scienc...  Audio   en
# 11  [British & Irish History, Guidebooks, Travel W...     CD   en

# %%
users.head()
# Out:
#     user_id                             location   age
# 16       17            chesapeake, virginia, usa   NaN
# 25       26            bellevue, washington, usa   NaN
# 38       39            cary, north carolina, usa   NaN
# 68       69  vancouver, british columbia, canada   NaN
# 77       78             oakland, california, usa  18.0

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# As a part of preprocessing, we will do the following steps:
# 1. Create new columns, city, state and country from the location column.
# 2. Remove the location column.
# 3. Fill the age column with mean of the group of city, state and country. If some are remaining, use overall mean.
# 4. Select columns to be used from book details. (For more details, see the next section)

# %% [markdown]
# ### Users Dataset

# %%
users["city"] = users["location"].str.split(", ").str[0]
users["state"] = users["location"].str.split(", ").str[1]
users["country"] = users["location"].str.split(", ").str[2]

# %%
groups = users.groupby(["city", "state", "country"]).groups
users_final = pd.DataFrame()
for group in tqdm(groups):
    temp_df = users.loc[groups[group]]
    if len(temp_df["age"].notnull()) == 0:
        users_final = pd.concat([users_final, temp_df], ignore_index=True)
    temp_df["age"].fillna(temp_df["age"].mean(), inplace=True)
    users_final = users_final.append(temp_df)
# Out:
#   0%|          | 0/10425 [00:00<?, ?it/s]

# %%
users_final["age"].isna().sum(), users["age"].isna().sum()
# Out:
# (3302, 12423)

# %%
users_final["age"].fillna(users_final["age"].mean(), inplace=True)
users_final["age"].isna().sum()
# Out:
# 0

# %%
users_final = users_final[["user_id", "age", "city", "state", "country"]]
users_final["age"] = users_final["age"].astype(int)
users_final.sort_values(by="user_id", inplace=True)
users_final.reset_index(drop=True, inplace=True)
users_final.head()
# Out:
#    user_id  age        city             state country
# 0       17   46  chesapeake          virginia     usa
# 1       26   38    bellevue        washington     usa
# 2       39   37        cary    north carolina     usa
# 3       69   34   vancouver  british columbia  canada
# 4       78   18     oakland        california     usa

# %% [markdown]
# ### The Books Dataset

# %% [markdown]
# We will be keeping all the rating columns, the review column and `num_pages` as they are just numbers. We will extract the year from publication date and keep it as a separate column. For series, we will create a boolean column that will be 1 if the book has a series and 0 otherwise. For authors, categories and columns, we will use one hot encoding if feasible.

# %%
columns_to_take = [
    "num_pages",
    "star_rating_1",
    "star_rating_2",
    "star_rating_3",
    "star_rating_4",
    "star_rating_5",
    "average_rating",
    "total_ratings",
    "total_reviews",
    "isbn",
    "publication_date",
    "series",
    "book_number_in_series",
    "authors",
    "categories",
    "format",
    "lang",
]

# %%
books = books[columns_to_take]
books["publication_date"] = pd.to_datetime(books["publication_date"])
books["publication_year"] = books["publication_date"].dt.year
books.drop(columns=["publication_date"], inplace=True)
books.head().T
# Out:
#                                                                      1   \
# num_pages                                                           870
# star_rating_1                                                     12455
# star_rating_2                                                     37005
# star_rating_3                                                    211781
# star_rating_4                                                    604283
# star_rating_5                                                   1493113
# average_rating                                                      4.5
# total_ratings                                                   2358637
# total_reviews                                                     29770
# isbn                                                         0439358078
# series                                                     Harry Potter
# book_number_in_series                                                 5
# authors                                                  [J.K. Rowling]
# categories             [Fantasy, Fantasy Books, Fantasy Books for Kids]
# format                                                               CD
# lang                                                                 en
# publication_year                                                   2004
#
#                                                                      3   \
# num_pages                                                           352
# star_rating_1                                                     11896
# star_rating_2                                                     49353
# star_rating_3                                                    288821
# star_rating_4                                                    706082
# star_rating_5                                                   1504505
# average_rating                                                     4.42
# total_ratings                                                   2560657
# total_reviews                                                       244
# isbn                                                         0439554896
# series                                                     Harry Potter
# book_number_in_series                                                 2
# authors                                                  [J.K. Rowling]
# categories             [Fantasy, Fantasy Books, Fantasy Books for Kids]
# format                                                               CD
# lang                                                                 en
# publication_year                                                   2003
#
#                                                                      4   \
# num_pages                                                           435
# star_rating_1                                                     10128
# star_rating_2                                                     24849
# star_rating_3                                                    194848
# star_rating_4                                                    630534
# star_rating_5                                                   1749958
# average_rating                                                     4.57
# total_ratings                                                   2610317
# total_reviews                                                     37093
# isbn                                                         043965548X
# series                                                     Harry Potter
# book_number_in_series                                                 3
# authors                                                  [J.K. Rowling]
# categories             [Fantasy, Fantasy Books, Fantasy Books for Kids]
# format                                                               CD
# lang                                                                 en
# publication_year                                                   2004
#
#                                                                       8   \
# num_pages                                                            815
# star_rating_1                                                       3443
# star_rating_2                                                       7613
# star_rating_3                                                      30030
# star_rating_4                                                      75683
# star_rating_5                                                     157499
# average_rating                                                      4.37
# total_ratings                                                     274268
# total_reviews                                                       4119
# isbn                                                          0345453743
# series                                  Hitchhiker's Guide to the Galaxy
# book_number_in_series                                                  5
# authors                                                  [Douglas Adams]
# categories             [Contemporary Fiction, Science Fiction, Scienc...
# format                                                             Audio
# lang                                                                  en
# publication_year                                                    2002
#
#                                                                       11
# num_pages                                                             55
# star_rating_1                                                        249
# star_rating_2                                                        985
# star_rating_3                                                       3342
# star_rating_4                                                       2409
# star_rating_5                                                       1408
# average_rating                                                      3.45
# total_ratings                                                       8393
# total_reviews                                                        503
# isbn                                                          0767915062
# series                                                        Standalone
# book_number_in_series                                                  1
# authors                                                    [Bill Bryson]
# categories             [British & Irish History, Guidebooks, Travel W...
# format                                                                CD
# lang                                                                  en
# publication_year                                                    2002

# %%
all_authors = set()
for authors in books["authors"].tolist():
    all_authors.update(authors)

len(all_authors)
# Out:
# 9968

# %% [markdown]
# There are about 10k distinct authors. I don't think we can use one hot encoding for this.

# %%
all_categories = set()
for categories in books["categories"].tolist():
    all_categories.update(categories)

len(all_categories)
# Out:
# 1560

# %% [markdown]
# Genre are all a lot. We will try to filter the top ones and use one hot encoding for them.

# %%
cat_counts = {}
for categories in books["categories"].tolist():
    for category in categories:
        if category in cat_counts:
            cat_counts[category] += 1
        else:
            cat_counts[category] = 1

# %%
cat_counts = {k: v for k, v in sorted(cat_counts.items(), key=lambda item: item[1], reverse=True)}

# %%
cat_counts_u = {k: v for k, v in cat_counts.items() if "books" not in k.lower()}
# Out:
# {'Contemporary Fiction': 5996,
#  'Science Fiction': 2564,
#  'Classic Books & Novels': 2143,
#  'Crime': 1991,
#  'Crime Fiction': 1991,
#  'Thriller Books': 1949,
#  'Thrillers': 1949,
#  'Adult & Contemporary Romance': 1568,
#  'Horror': 1336,
#  'Historical Fiction': 1260,
#  'Historical Romance': 1146,
#  "Children's Fiction": 1100,
#  'Romance': 1086,
#  'Romance Books': 1086,
#  'Adventure Books': 1063,
#  'Biography: General': 993,
#  'Fantasy': 900,
#  'Fantasy Books': 900,
#  'Short Story Books': 872,
#  'Sagas': 836,
#  'Funny Books & Stories': 677,
#  'Espionage': 622,
#  'Political & Legal': 582,
#  'Classic Books for Children': 533,
#  'Memoirs': 532,
#  'Anthologies (non-poetry)': 529,
#  'Literary Studies: General': 527,
#  'Space Opera': 490,
#  'Mind, Body, Spirit: Thought & Practice': 483,
#  "Children's General Story Books": 482,
#  'History Of The Americas': 466,
#  'Poetry By Individual Poets': 451,
#  'Family': 450,
#  'Religious & Spiritual Fiction': 441,
#  'Adventure Books for Kids': 436,
#  'Biography: Historical, Political & Military': 417,
#  'Animal Stories': 395,
#  'Plays, Playscripts': 391,
#  'Graphic Novels, Anime & Manga': 378,
#  'Literary Essays': 371,
#  'Funny Books for Kids': 362,
#  'Sci Fi Books for Kids': 359,
#  'Popular Psychology': 352,
#  'Personal Development': 341,
#  'Historical Crime': 336,
#  'Miscellaneous Items': 307,
#  'Christian Life & Practice': 305,
#  'Guidebooks': 290,
#  'Religious Life & Practice': 287,
#  'Biography: Literary': 285,
#  'Military Fiction': 279,
#  'Travel Writing': 276,
#  'Psychology': 275,
#  'Vintage Crime': 274,
#  'Assertiveness, Motivation & Self-esteem': 268,
#  'Biography: Arts & Entertainment': 268,
#  'Gender Studies: Women': 267,
#  'Cartoons & Comic Strips': 260,
#  'Mind, Body & Spirit': 256,
#  'Spirituality & Religious Experience': 233,
#  'Family & Relationships': 226,
#  'Science: General Issues': 222,
#  'Fantasy Books for Kids': 216,
#  'English Language: Reading Schemes': 208,
#  'European History': 206,
#  'Social & Cultural History': 200,
#  'Family Issues': 199,
#  'Graphic Novels: Literary & Memoirs': 194,
#  'Television': 188,
#  'Films, Cinema': 186,
#  'Natural History Books': 185,
#  'Historical': 182,
#  'Advice On Careers & Achieving Success': 180,
#  'Politics & Government': 178,
#  'Westerns': 177,
#  'Teaching Resources & Education': 172,
#  'Military History': 172,
#  'Philosophy': 171,
#  'Theatre Studies': 167,
#  'General Cookery': 167,
#  'People & Places': 166,
#  'Complementary Therapies, Healing & Health': 165,
#  'Literary Studies: Fiction, Novelists & Prose Writers': 163,
#  'Business & Management': 160,
#  'Autobiography: General': 160,
#  'Parodies & Spoofs': 151,
#  'Psychic Powers & Psychic Phenomena': 143,
#  'Erotic Fiction': 142,
#  'Advice On Parenting': 141,
#  'Sociology': 141,
#  'British & Irish History': 139,
#  'Folklore, Myths & Legends': 137,
#  'Christian Books': 137,
#  'Graphic Novels: Manga': 136,
#  'Biography: Science, Technology & Engineering': 135,
#  'Myth & Legend Told As Fiction': 134,
#  'Poetry Books for Kids': 130,
#  'Dating, Relationships, Living Together & Marriage': 129,
#  'Shakespeare Plays': 129,
#  'General & World History': 129,
#  'Mysticism, Magic & Ritual': 129,
#  'Popular Medicine & Health': 128,
#  'Christian Theology': 126,
#  'Traditional': 125,
#  'Popular Culture': 123,
#  'Literary Studies: From C 1900 -': 123,
#  'Study & Learning Skills: General': 122,
#  'Language Teaching & Learning Material & Coursework': 121,
#  'Black & Asian Studies': 121,
#  'Reference Works': 120,
#  '20th Century History: C 1900  To C 2000': 119,
#  'Society & Culture: General': 119,
#  'Asian History': 119,
#  'True Crime Biographies': 116,
#  'True Crime Books': 116,
#  'Religion: General': 116,
#  'Picture Books': 115,
#  'Social & Cultural Anthropology': 114,
#  'Graphic Novels: True Stories & Non-fiction': 114,
#  'Popular Science': 113,
#  'Buddhist Books': 111,
#  'Health Books': 111,
#  'Witchcraft & Wicca': 110,
#  'Mind, Body, Spirit: Meditation & Visualisation': 110,
#  'School Stories': 109,
#  'Oriental & Indian Philosophy': 108,
#  'Creative Writing & Creative Writing Guides': 108,
#  'Ethics & Moral Philosophy': 108,
#  'Rock & Pop Music': 108,
#  'Biography: Religious & Spiritual': 107,
#  'Personal Christian Testimony & Popular Inspirational Works': 107,
#  'World War 2 Books': 105,
#  'Mystery Books for Kids': 102,
#  'History Of Science': 102,
#  'Early Learning': 101,
#  'Magic, Spells & Alchemy': 99,
#  'Modern History To 20th Century: C 1700 To C 1900': 98,
#  'Writing & Editing Guides': 96,
#  'Evolution': 96,
#  'Philosophy Of Science': 95,
#  'Encyclopaedias & Reference Works': 94,
#  'Diets & Dieting': 93,
#  'Society & Social Issues': 91,
#  'Jokes & Riddles': 91,
#  'Political Science & Theory': 90,
#  'Fiction In Translation': 89,
#  'Comparative Religion': 86,
#  'Diaries, Letters & Journals': 86,
#  'Teaching Skills & Techniques': 86,
#  'Poetry Books': 86,
#  'Graphic Novels': 86,
#  'Poetry Anthologies (various Poets)': 85,
#  'Management: Leadership & Motivation': 84,
#  'Economics': 84,
#  'Philosophy Of Religion': 84,
#  'Relationships': 84,
#  'Humour Collections & Anthologies': 83,
#  'Film Theory & Criticism': 82,
#  'Literary Studies: Plays & Playwrights': 81,
#  'Indigenous Peoples': 80,
#  'Physics Books': 80,
#  'National & Regional Cuisine': 80,
#  'Dance & Other Performing Arts': 80,
#  'Social, Group Or Collective Psychology': 79,
#  'Literary Studies: Poetry & Poets': 79,
#  'Wildlife: General Interest': 79,
#  'Dogs As Pets': 78,
#  'Dictionaries & Dictionary Books': 78,
#  'Cultural Studies': 76,
#  'Abnormal Psychology': 74,
#  "Children's Health Books": 74,
#  'Prose: Non-fiction': 73,
#  'Food & Drink': 73,
#  'Biblical Studies & Exegesis': 73,
#  'Individual Actors & Performers': 72,
#  'Philosophy & Theory Of Education': 70,
#  'Individual Composers & Musicians, Specific Bands & Groups': 70,
#  'English Language: Reading & Writing Skills': 69,
#  'Feminism & Feminist Theory': 69,
#  'Religious Books': 68,
#  'Domestic Animals & Pets': 68,
#  'Jewish Books': 67,
#  'Autobiography: Arts & Entertainment': 66,
#  'Music Reviews & Criticism': 66,
#  'Management & Management Techniques': 65,
#  'Constitution: Government & The State': 64,
#  'Communication Studies': 64,
#  'Radio': 64,
#  'Literary Studies: Classical, Early & Medieval': 63,
#  'Characters': 63,
#  'Anthropology': 63,
#  'Stationery': 63,
#  'Language Readers': 62,
#  'Educational Strategies & Policy': 62,
#  'Psychotherapy': 62,
#  'Film Scripts & Screenplays': 62,
#  'Conservation Of The Environment': 61,
#  'Social & Political Philosophy': 61,
#  'Classical History / Classical Civilisation': 61,
#  'History Books for Kids': 61,
#  'Gender Studies, Gender Groups': 61,
#  'Teaching Of A Specific Subject': 60,
#  'Self-Esteem': 60,
#  'History Of Religion': 60,
#  'Western Philosophy, From C 1900 -': 59,
#  'Coping With Illness': 59,
#  'Aspects Of Religion (non-Christian)': 59,
#  'Linguistics': 58,
#  'Sociology: Customs & Traditions': 58,
#  'English Literature': 58,
#  'International Relations': 58,
#  'Classic Science Fiction': 58,
#  'Music': 58,
#  'Nonfiction History Books for Kids': 57,
#  'Child & Developmental Psychology': 57,
#  'Early Modern History: C 1450/1500 To C 1700': 56,
#  'Romance Books for Teenagers': 56,
#  'Biology, Life Sciences': 56,
#  'Economic History': 56,
#  'Personal Finance': 55,
#  'Social Issues': 55,
#  'Quick & Easy Cooking': 55,
#  'Biography: Sport': 54,
#  'Cognition & Cognitive Psychology': 54,
#  'Usage & Grammar Guides': 54,
#  'Political Economy': 54,
#  'Cats As Pets': 54,
#  'Classic Horror': 54,
#  'Crafts & Hobbies': 53,
#  'Unexplained Phenomena / The Paranormal': 53,
#  'Coping With Death & Bereavement': 53,
#  'Health & Wholefood Cookery': 52,
#  'Autobiography: Historical, Political & Military': 52,
#  'Higher & Further Education, Tertiary Education': 52,
#  'Ancient History: To C 500 CE': 52,
#  'Sports Books': 51,
#  'African History': 51,
#  'Coping With Personal Problems': 51,
#  'Self, Ego, Identity, Personality': 51,
#  'Astrology': 50,
#  'Primary & Middle Schools': 50,
#  'Vegetarian Cookery': 50,
#  'Astronomy, Space & Time': 49,
#  'Geographical Discovery & Exploration': 49,
#  'Middle Eastern History': 49,
#  'Postwar 20th Century History, From C 1945 To C 2000': 49,
#  'Media Studies': 49,
#  'Popular Astronomy & Space': 49,
#  'Applied Ecology': 49,
#  'Citizenship & Social Education': 48,
#  'Graphic Novels: Superheroes': 48,
#  'Language: Reference & General': 47,
#  'Biography: Business & Industry': 47,
#  'Impact Of Science & Technology On Society': 47,
#  'Sports Stories': 47,
#  'Comic Book & Cartoon Art': 47,
#  'Economic Theory & Philosophy': 46,
#  'Zen Buddhism': 46,
#  'Literature: History & Criticism': 46,
#  'Medieval History': 46,
#  'Sociology & Anthropology': 46,
#  'Christian Aspects Of Sexuality, Gender & Relationships': 46,
#  'Child Care & Upbringing': 45,
#  'Historical Adventure': 45,
#  'Medicine': 45,
#  'Poetry & Drama': 45,
#  'Other Non-Christian Religions': 45,
#  'Wildlife: Mammals': 45,
#  'ELT: Learning Material & Coursework': 44,
#  'Other Performing Arts': 44,
#  'Physiological & Neuro-psychology, Biopsychology': 44,
#  'Art History': 44,
#  'Development Economics': 44,
#  'Sociology: Family & Relationships': 44,
#  'Entrepreneurship': 44,
#  'Central Government Policies': 43,
#  'Cosmology & The Universe': 43,
#  'Environmental Science, Engineering & Technology': 43,
#  'Mysticism': 43,
#  'History Of Western Philosophy': 43,
#  'Television Scripts & Screenplays': 42,
#  'Political Control & Freedoms': 42,
#  'Autobiography: Literary': 42,
#  'Horror & Ghost': 42,
#  'Urban Communities': 41,
#  'Military Engineering': 41,
#  'Sex & Sexuality, Sex Manuals': 40,
#  'Jokes & Humour': 40,
#  'Roman Catholicism, Roman Catholic Church': 40,
#  'Cosmetics, Hair & Beauty': 39,
#  'Civil Rights & Citizenship': 39,
#  'World War 2 Fiction': 39,
#  'Fortune-telling & Divination': 39,
#  'Regional Studies': 38,
#  'Ethnic Studies': 38,
#  'Dreams & Their Interpretation': 38,
#  'Biography: Royalty': 38,
#  'Sexual Behaviour': 38,
#  'Christian Spirituality & Religious Experience': 38,
#  'Holocaust': 37,
#  "Women's Health": 37,
#  'Anthologies': 37,
#  'Terrorism, Armed Struggle': 36,
#  'Musical Scores, Lyrics & Libretti': 36,
#  'Technology: General Issues': 36,
#  'Adult Literacy Guides & Handbooks': 36,
#  'Islamic Story & History Books': 36,
#  'Short Stories for Kids': 36,
#  'Traditional Medicine & Herbal Remedies': 36,
#  'Archaeology': 36,
#  "Children's Foreign Language Books": 36,
#  'Hindu Books': 36,
#  'Hobby and Gaming Books': 36,
#  'Early History: C 500 To C 1450/1500': 36,
#  'Language Phrasebooks': 36,
#  'Human Biology': 35,
#  'Western Philosophy: Ancient, To C 500': 35,
#  'Literary Theory': 34,
#  'Literary Studies: C 1800 To C 1900': 34,
#  'Spirit Guides, Angels & Channelling': 34,
#  'Crime & Criminology': 34,
#  'Neurology & Clinical Neurophysiology': 34,
#  'Exercise & Workout Books': 34,
#  'Political Structure & Processes': 33,
#  'Reincarnation & Past Lives': 33,
#  'Semantics': 33,
#  'Psychology: Emotions': 33,
#  'Mathematics': 33,
#  'Interior Design, Decor & Style Guides': 33,
#  'Popular Beliefs & Controversial Knowledge': 32,
#  'True Story Books': 32,
#  'History Of Engineering & Technology': 32,
#  'ELT Graded Readers': 32,
#  'Storybooks': 32,
#  'Social Discrimination': 32,
#  'Acting Techniques': 32,
#  'Adult Education, Continuous Learning': 32,
#  'Organization & Management Of Education': 32,
#  'History Of Medicine': 32,
#  'Coping With Stress': 31,
#  'Painting & Art Manuals': 31,
#  'Dictionaries Of Quotations': 31,
#  'Shakespeare Studies & Criticism': 31,
#  'Individual Artists, Art Monographs': 31,
#  'Art Books': 31,
#  'Tibetan Buddhism': 31,
#  'Economic Systems & Structures': 30,
#  'Wildlife: Birds & Birdwatching': 30,
#  'Dinosaurs & The Prehistoric World': 30,
#  'Thesauri': 30,
#  'Cookery By Ingredient': 30,
#  'Philosophy Of Mind': 29,
#  'Computing: General': 29,
#  'Warfare & Defence': 29,
#  'Ecological Science, The Biosphere': 29,
#  'DIY: General': 29,
#  'Philosophy: Metaphysics & Ontology': 29,
#  'Palaeontology': 29,
#  'Cookery Dishes & Courses': 29,
#  'Safety In The Home': 29,
#  'Human Rights': 29,
#  'Fiction Texts': 29,
#  'Investment & Securities': 28,
#  'Study & Revision Guides': 28,
#  'Sociology: Death & Dying': 28,
#  'Vietnam War': 28,
#  'Feng Shui': 28,
#  'Journalistic Style Guides': 28,
#  'Social Groups': 28,
#  'Zoology & Animal Sciences': 28,
#  'Prayer': 28,
#  'Christian Worship, Rites & Ceremonies': 28,
#  'Open Learning, Home Learning, Distance Education': 28,
#  'Wildlife': 28,
#  'Astrophysics': 27,
#  'Rocks, Minerals & Fossils': 27,
#  'Death & Bereavement': 27,
#  'Ships & Shipping': 27,
#  'Psychoanalytical Theory (Freudian Psychology)': 27,
#  'UFOs & Extraterrestrial Beings': 27,
#  'Cooking With Specific Gadgets': 27,
#  'Bilingual & Multilingual Dictionaries': 27,
#  'Gender Studies: Men': 26,
#  'Cookery For Dietary Conditions': 26,
#  'Drawing': 26,
#  'International Economics': 26,
#  'Students & Student Organisations': 26,
#  'Taoism': 26,
#  'Techniques Of Music / Music Tutorials': 26,
#  'Peace Studies & Conflict Resolution': 26,
#  'Pregnancy, Birth & Baby Care': 26,
#  'Marxism & Communism': 26,
#  'Theology': 26,
#  'World Atlases / World Maps': 26,
#  'Educational Psychology': 26,
#  'School/community Relations & School/home Relations': 26,
#  'Public Speaking Guides': 26,
#  'Travel & Holiday Guides': 25,
#  'Spiritualism': 25,
#  'Shamanism, Paganism & Druidry': 25,
#  'Clairvoyance & Precognition': 25,
#  'Earth: Natural History General': 25,
#  'Jewish Studies': 25,
#  'Complementary Medicine': 25,
#  'Research Methods: General': 25,
#  'Slavery & Abolition Of Slavery': 25,
#  'Baby Books': 25,
#  'Geology & The Lithosphere': 24,
#  'Physical Anthropology & Ethnography': 24,
#  'Relativity Physics': 24,
#  'Literary Reference Works': 24,
#  'Sales & Marketing': 24,
#  'Antiques & Collectables': 24,
#  'Trees, Wildflowers & Plants': 24,
#  'Home Renovation & Extension': 24,
#  'American Civil War': 24,
#  'History: Specific Events & Topics': 24,
#  'Siblings': 24,
#  'Teaching Of Specific Groups & Persons With Special Educational Needs': 24,
#  'Multicultural Education': 24,
#  'Buddhist Worship, Rites & Ceremonies': 24,
#  'Carving & Modelling, Moulding & Casting': 23,
#  'Tribal Religions': 23,
#  'Psychiatry': 23,
#  'Numbers & Counting': 23,
#  'History Of Mathematics': 23,
#  'War & Defence Operations': 23,
#  'Political Leaders & Leadership': 23,
#  'Tips & Advice': 23,
#  'Activity Books': 23,
#  'Parties, Etiquette & Entertaining': 23,
#  "Children's Hobby & Gaming Books": 22,
#  'Social Classes': 22,
#  'Climbing & Mountaineering': 22,
#  'Careers Guidance': 22,
#  'Gay Studies (Gay Men)': 22,
#  'Media, Information & Communication Industries': 22,
#  'Central Government': 22,
#  'Mental Health Services': 22,
#  'Art & Design': 22,
#  'Contemporary Non-Christian & Para-Christian Cults & Sects': 22,
#  'Gardening Books': 22,
#  'Clinical Psychology': 22,
#  'Household Hints': 22,
#  'Historical & Comparative Linguistics': 21,
#  'Aerospace & Aviation Technology': 21,
#  'Veterinary Medicine': 21,
#  'Natural History Books for Children': 21,
#  'Multiculturalism': 21,
#  'Baseball': 21,
#  'Natural Disasters': 21,
#  'Quantum Physics (quantum Mechanics & Quantum Field Theory)': 20,
#  'Teenagers: Advice For Parents': 20,
#  'Animals & Society': 20,
#  'Language Teaching & Learning (other Than ELT)': 20,
#  'Western Philosophy: Medieval & Renaissance, C 500 To C 1600': 20,
#  'Curriculum Planning & Development': 20,
#  'Industrial Relations': 19,
#  'Autobiography: Sport': 19,
#  'Internet Guides & Online Services': 19,
#  'Press & Journalism': 19,
#  'General Reference': 19,
#  'Art': 19,
#  'Bullying & Abuse': 19,
#  'Genetics (non-medical)': 19,
#  'Christian Ministry & Pastoral Activity': 19,
#  'Jewellery & Beadcraft': 19,
#  'Aircraft': 19,
#  'Industrial / Commercial Art & Design': 19,
#  'Professional Interior Design': 19,
#  'Finance': 18,
#  'Philosophy: Epistemology & Theory Of Knowledge': 18,
#  'Classic Travel Writing': 18,
#  'Art Theory': 18,
#  'Criminal Law & Procedure': 18,
#  'Botany & Plant Sciences': 18,
#  'Illness & Addiction: Social Aspects': 18,
#  'Infectious & Contagious Diseases': 18,
#  'Computer Science': 18,
#  "Children's Reference Books": 18,
#  "Children's Religious Books": 18,
#  'Organizational Theory & Behaviour': 18,
#  'Religious Groups: Social & Cultural Aspects': 18,
#  'Star Signs & Horoscopes': 18,
#  'Judaism: Worship, Rites & Ceremonies': 18,
#  'Dog Obedience & Training': 18,
#  'Animated Films': 18,
#  'Literary Studies: C 1500 To C 1800': 18,
#  'Teaching Of Students With English As A Second Language (TESOL)': 18,
#  'Coping With Drug & Alcohol Abuse': 17,
#  'General Study Books': 17,
#  "Children's Literature Studies: General": 17,
#  'Screenwriting Techniques': 17,
#  'Basketball': 17,
#  'Chemistry Books': 17,
#  'Non-Fiction': 17,
#  'The Environment': 17,
#  'Age Groups: Children': 17,
#  'Behavioural Theory (Behaviourism)': 17,
#  'Coping With Old Age': 17,
#  'Lesbian Studies': 17,
#  'English Language': 17,
#  'Battles & Campaigns': 17,
#  'Business Strategy': 17,
#  'Puzzle Books': 17,
#  'Wildlife: Aquatic Creatures': 16,
#  'Industrial Or Vocational Training': 16,
#  'Revolutions, Uprisings, Rebellions': 16,
#  'Public Health & Preventive Medicine': 16,
#  'Operating Systems': 16,
#  'Art Techniques & Principles': 16,
#  'Political Structures: Democracy': 16,
#  'Cakes, Baking, Icing & Sugarcraft': 16,
#  'Graphic Novels: History & Criticism': 16,
#  'Picture & Activity Books': 16,
#  'Constitutional & Administrative Law': 16,
#  'Pre-school & Kindergarten': 16,
#  'Sciences': 16,
#  'Ancient Religions & Mythologies': 16,
#  'Paintings': 16,
#  'General Encyclopaedias': 16,
#  'Earth Sciences': 15,
#  'Jurisprudence': 15,
#  'Management Of Land & Natural Resources': 15,
#  'Ethical & Social Aspects Of Computing': 15,
#  'Weather': 15,
#  'Naval Forces & Warfare': 15,
#  'Bible Readings, Selections & Meditations': 15,
#  'Rural Communities': 15,
#  'Coping With Disability': 15,
#  'Christian Mission & Evangelism': 15,
#  'Ice-skating': 15,
#  'Combat Sports & Self-defence': 15,
#  'Agriculture & Farming': 15,
#  'Microsoft Windows': 15,
#  "Mysteries & The Supernatural (Children's/YA)": 14,
#  'Health Systems & Services': 14,
#  'World War 1 Books': 14,
#  'Violence In Society': 14,
#  'Poverty  & Unemployment': 14,
#  'Places & Peoples: Pictorial Works': 14,
#  'Bibles': 14,
#  'Architecture': 14,
#  'Education: Care & Counselling Of Students': 14,
#  'Satanism & Demonology': 14,
#  'Medical Study & Revision Guides & Reference Material': 14,
#  'Probability & Statistics': 14,
#  'Astral Projection & Out-of-body Experiences': 14,
#  'Social Forecasting, Future Studies': 14,
#  'Personnel & Human Resources Management': 14,
#  'Art History: c 1900 -': 14,
#  'Analytical & Jungian Psychology': 14,
#  'DIY: Carpentry & Woodworking': 14,
#  'Reiki': 14,
#  'Biology': 14,
#  'True Stories Of Heroism, Endurance & Survival': 14,
#  'Teaching Of Students With Specific Learning Difficulties / Needs': 14,
#  'Dictionaries for Kids': 14,
#  'Secondary Schools': 14,
#  'Pharmacology': 13,
#  'Religious Studies': 13,
#  'Oceanography (seas)': 13,
#  'Horses & Ponies': 13,
#  'Nature & Existence Of God': 13,
#  'Political Ideologies': 13,
#  'History Of Ideas': 13,
#  'Small Businesses & Self-employed': 13,
#  'Weddings, Wedding Planners': 13,
#  'Lettering & Calligraphy': 13,
#  'Sufism & Islamic Mysticism': 13,
#  'Literacy': 13,
#  'Needlework & Fabric Crafts': 13,
#  'Antiques & Collectables: Books, Manuscripts, Ephemera & Printed Matter': 13,
#  'Aromatherapy & Essential Oils': 13,
#  'Tarot': 13,
#  'First Words': 13,
#  'Rural Crafts': 12,
#  'Drama': 12,
#  'Conservation Of Wildlife & Habitats': 12,
#  'Literary Companions': 12,
#  'Individual Film Directors, Film-makers': 12,
#  'ABC': 12,
#  'Philosophy: Logic': 12,
#  'Diplomacy': 12,
#  'Pottery, Ceramics & Glass Crafts': 12,
#  'Ethnic Minorities & Multicultural Studies': 12,
#  'Psychological Theory & Schools Of Thought': 12,
#  'Neurosciences': 12,
#  'DIY: House Maintenance Manuals': 12,
#  'Film Guides & Reviews': 12,
#  'Autobiography: Religious & Spiritual': 12,
#  'Animal Husbandry': 12,
#  'Christian Institutions & Organizations': 12,
#  'Local History': 12,
#  'Autobiography: Business & Industry': 12,
#  "Children's Christian Books": 12,
#  'Penology & Punishment': 12,
#  'Autobiography: Science, Technology & Engineering': 12,
#  'Human Geography': 12,
#  'Genealogy, Heraldry, Names & Honours': 12,
#  "Dictionaries Of Biography (Who's Who)": 12,
#  'Dietetics & Nutrition': 12,
#  'Accounting': 12,
#  'Beverages': 12,
#  'Industry & Industrial Studies': 12,
#  'Rap & Hip-Hop': 12,
#  'Diseases & Disorders': 12,
#  'Fitness & Diet': 12,
#  'Phonetics, Phonology': 12,
#  'Development Studies': 12,
#  'Grammar & Vocabulary': 12,
#  'Jazz': 12,
#  'Toys: Making & Decorating': 12,
#  'Time (chronology), Time Systems & Standards': 11,
#  'Computer Networking & Communications': 11,
#  'Child Abuse': 11,
#  'Wildlife: Butterflies, Other Insects & Spiders': 11,
#  'Globalization': 11,
#  'Popular Philosophy': 11,
#  'Islamic Studies': 11,
#  'Sailing': 11,
#  'Alternative Belief Systems': 11,
#  'Meteorology & Climatology': 11,
#  'Graphical & Digital Media Applications': 11,
#  'Art History: From c 1960': 11,
#  'Management Decision Making': 11,
#  'Social Impact Of Disasters': 11,
#  'Training & Coaching': 11,
#  'TV Tie-in Humour': 11,
#  'Outdoor Survival Skills': 11,
#  'Flower Arranging & Floral Crafts': 11,
#  'Oriental Martial Arts': 11,
#  'Science': 11,
#  'Photographs: Collections': 11,
#  'Verse': 11,
#  '21st Century History: From C 2000 -': 11,
#  'Disability': 11,
#  'Sign Languages, Braille & Other Linguistic Communication': 10,
#  'Service Industries': 10,
#  'Religious Fundamentalism': 10,
#  'Cycling': 10,
#  'Cybernetics & Systems Theory': 10,
#  'Colours': 10,
#  'Religion & Science': 10,
#  'Mathematical Logic': 10,
#  'Philosophy: Aesthetics': 10,
#  'Food Manufacturing & Related Industries': 10,
#  'Air Forces & Warfare': 10,
#  'Photographic Reportage': 10,
#  'Intergenerational Relationships': 10,
#  'Christian Prayerbooks': 10,
#  'History Of Architecture': 10,
#  'Yearbooks, Annuals, Almanacs': 10,
#  'Folk & Traditional Music': 10,
#  'Social Theory': 10,
#  'Epidemiology & Medical Statistics': 10,
#  'Land Forces & Warfare': 10,
#  'Trains & Railways': 10,
#  'Punk, New Wave & Indie': 10,
#  'Labour Economics': 10,
#  'Business Communication & Presentation': 10,
#  'Fascism & Nazism': 10,
#  'Paediatric Medicine': 10,
#  'Gardening: Flowers': 10,
#  'Social Research & Statistics': 10,
#  'Size & Shape': 10,
#  'Conspiracy Theories': 10,
#  'Sociolinguistics': 10,
#  'Specialized Gardening Methods': 10,
#  'Prayers & Liturgical Material': 10,
#  'Golf': 10,
#  'Australasian & Pacific History': 10,
#  'Worship, Rites & Ceremonies': 10,
#  'Decorative Wood & Metalwork': 10,
#  'Examinations & Assessment': 10,
#  'Ice Hockey': 10,
#  'Homoeopathy': 10,
#  'Dinosaurs': 10,
#  'Country & Western Music': 10,
#  'Nuclear Structure Physics': 9,
#  'Space Science': 9,
#  'Business Ethics': 9,
#  'Occult Studies': 9,
#  'Personal & Public Health': 9,
#  'Advertising': 9,
#  'Winter Sports': 9,
#  'Pets': 9,
#  'Maritime History': 9,
#  'Fashion & Society': 9,
#  'Forensic Medicine': 9,
#  'Psychological Methodology': 9,
#  'Consumer Advice': 9,
#  'Artificial Intelligence': 9,
#  'Migration, Immigration & Emigration': 9,
#  'PSHE': 9,
#  'Anatomy': 9,
#  'Fashion & Textiles: Design': 9,
#  'Plays': 9,
#  'Christian Social Thought & Activity': 9,
#  'Quiltmaking, Patchwork & Applique': 9,
#  'Religious Institutions & Organizations': 9,
#  'Life Sciences: General Issues': 9,
#  "Children's Stationery": 9,
#  'Disability: Social Aspects': 9,
#  'Marine Biology': 9,
#  'Knitting & Crochet': 9,
#  'Embroidery Crafts': 9,
#  'Sleep & Dreams': 9,
#  'Slang & Dialect Humour': 9,
#  'Urban & Municipal Planning': 8,
#  'Religious & Spiritual Leaders': 8,
#  'Dance': 8,
#  'Ballet': 8,
#  'Legal History': 8,
#  'Western Philosophy: C 1600 To C 1900': 8,
#  'Historiography': 8,
#  'Food & Society': 8,
#  'Alcoholic Beverages': 8,
#  'Heavy Metal Music': 8,
#  'Animal Behaviour': 8,
#  'Non-Western Philosophy': 8,
#  'HIV / AIDS': 8,
#  'Teaching Staff': 8,
#  'Sacred & Religious Music': 8,
#  'Science & Geography': 8,
#  'Microbiology (non-medical)': 8,
#  'Translation & Interpretation': 8,
#  'Industrial Chemistry & Manufacturing Technologies': 8,
#  'Agriculture & Related Industries': 8,
#  'Environment': 8,
#  'Technology': 8,
#  'Drug & Substance Abuse: Social Aspects': 8,
#  'Political Oppression & Persecution': 8,
#  'Practical Interests': 8,
#  'Endangered Species & Extinction Of Species': 8,
#  'Conjuring & Magic': 8,
#  'DNA & Genome': 8,
#  'Judaism: Sacred Texts': 8,
#  'Writing Skills': 8,
#  'Horse Racing': 8,
#  'Semiotics / Semiology': 8,
#  'Religious Subjects Depicted In Art': 8,
#  'Musicals': 8,
#  'International Trade': 8,
#  'Number Theory': 8,
#  'Birds, Including Cage Birds, As Pets': 8,
#  'Music: Styles & Genres': 8,
#  'Defence Strategy, Planning & Research': 8,
#  'Opera': 8,
#  'Espionage & Secret Services': 8,
#  'UNIX': 8,
#  'Transportation Books for Children': 8,
#  'Mathematical Physics': 7,
#  'History Of Other Lands': 7,
#  'Football (Soccer, Association Football)': 7,
#  'Surgery': 7,
#  'Ghosts & Poltergeists': 7,
#  'World War 1 Fiction': 7,
#  'Electronics Engineering': 7,
#  'Antiques & Collectables: Ceramics & Glass': 7,
#  'Calculus': 7,
#  'Criminal Procedure': 7,
#  'Phenomenology & Existentialism': 7,
#  "Children's Sports Books": 7,
#  'Social Work': 7,
#  'Conservatism & Right-of-centre Democratic Ideologies': 7,
#  'Building Construction & Materials': 7,
#  'Pollution & Threats To The Environment': 7,
#  'Separation & Divorce': 7,
#  'Advice On Education': 7,
#  'Walking, Hiking, Trekking': 7,
#  'Veterinary Medicine: Small Animals (pets)': 7,
#  'Organic Gardening': 7,
#  'Colonialism & Imperialism': 7,
#  'Historical Jesus': 7,
#  'Family Break-Up': 7,
#  'Intelligence & Reasoning': 7,
#  'Engineering: General': 7,
#  'Witchcraft': 7,
#  'Demonstrations & Protest Movements': 7,
#  'Preserving & Freezing': 7,
#  'Language Self-study Texts': 7,
#  'Antiques & Collectables: Carpets, Rugs & Textiles': 7,
#  'Massage': 7,
#  'Finance & Accounting': 7,
#  'Applied Mathematics': 7,
#  'Aquaculture & Fish-farming: Practice & Techniques': 7,
#  'Revolutionary Groups & Movements': 7,
#  'Theatre Direction & Production': 7,
#  'Judaism: Theology': 7,
#  'Christian Prayer': 7,
#  'Battles': 7,
#  'Information Technology Industries': 7,
#  'Laws Of Specific Jurisdictions': 7,
#  'Judaism: Mysticism': 7,
#  'Physiology': 7,
#  'Office & Workplace': 6,
#  'Other Nonconformist & Evangelical Churches': 6,
#  'Social Issues & Processes': 6,
#  'Social Welfare & Social Services': 6,
#  'Fishing, Angling': 6,
#  'Gay & Lesbian Studies': 6,
#  'Bible Stories': 6,
#  'Boating': 6,
#  'Propaganda': 6,
#  'Non-graphic Art Forms': 6,
#  'Photography': 6,
#  'Historical Geography': 6,
#  'Computer Programming / Software Development': 6,
#  'Programming & Scripting Languages: General': 6,
#  'Pop-Up Books': 6,
#  'Western Classical Music': 6,
#  'Archaeology By Period / Region': 6,
#  'Celtic Religion & Mythology': 6,
#  'Ownership & Organization Of Enterprises': 6,
#  'Manufacturing Industries': 6,
#  'Music Industry': 6,
#  'Microeconomics': 6,
#  'Fashion Design & Theory': 6,
#  'Christian Instruction': 6,
#  'Writing Systems, Alphabets': 6,
#  'Garden Design & Planning': 6,
#  'Sex Education': 6,
#  'Library & Information Sciences': 6,
#  'Chakras, Auras & Spiritual Energy': 6,
#  'Gnosticism': 6,
#  'Military Life & Institutions': 6,
#  'Scientific Equipment, Experiments & Techniques': 6,
#  'Legal Profession: General': 6,
#  'Special & Elite Forces': 6,
#  'Chaos Theory': 6,
#  'Tennis': 6,
#  'Sexual Abuse & Harassment': 6,
#  'Theory Of Music & Musicology': 6,
#  'Countryside, Country Life': 6,
#  'E-commerce: Business Aspects': 6,
#  'Solar System: The Sun & Planets': 6,
#  'Astronautics': 6,
#  'Dialect, Slang & Jargon': 6,
#  'Biotechnology': 6,
#  'Environmental Economics': 6,
#  'Sustainability': 6,
#  'Schools': 6,
#  'Reggae': 6,
#  'Therapy & Therapeutics': 6,
#  'Mathematics & Numeracy': 6,
#  'Oriental Art': 6,
#  'Weapons & Equipment': 6,
#  'Annuals': 6,
#  'Religion & Beliefs': 6,
#  'Biblical Commentaries': 6,
#  'Encyclopaedias': 6,
#  'Book & Paper Crafts': 6,
#  'Light Orchestral & Big Band Music': 6,
#  'Primates': 6,
#  'Aviation Skills / Piloting': 6,
#  'Legal Ethics & Professional Conduct': 6,
#  'Cartoons': 6,
#  'Schools Inspection (& Preparing For Inspection)': 6,
#  'Particle & High-energy Physics': 5,
#  'Political Activism': 5,
#  'Experimental Psychology': 5,
#  'Food & Cookery': 5,
#  "Witches & Ghosts (Children's/YA)": 5,
#  'Systems Analysis & Design': 5,
#  'Prints': 5,
#  'Wines': 5,
#  'Organized Crime': 5,
#  'Religious Intolerance, Persecution & Conflict': 5,
#  'Skiing': 5,
#  'Time & Seasons': 5,
#  'City & Town Planning - Architectural Aspects': 5,
#  'Time Management': 5,
#  'Desserts': 5,
#  'Numerology': 5,
#  'Gardening: Growing Fruit & Vegetables': 5,
#  'Eclectic & Esoteric Religions & Belief Systems': 5,
#  'Zoology: Mammals': 5,
#  'True War  & Combat Stories': 5,
#  'Counselling & Advice Services': 5,
#  'Sociology: Work & Labour': 5,
#  'Inventions & Inventors': 5,
#  'Main Courses': 5,
#  'Television Technology': 5,
#  'Olympic Games': 5,
#  'Agronomy & Crop Production': 5,
#  'Nationalism': 5,
#  'Christian Mysticism': 5,
#  'Geography Books': 5,
#  'Religion & Politics': 5,
#  'Cooking With Fish & Seafood': 5,
#  'Gynaecology & Obstetrics': 5,
#  'Medical Profession': 5,
#  'Aerospace & Air Transport Industries': 5,
#  'Spinning & Weaving': 5,
#  'Religious Communities & Monasticism': 5,
#  'Cooking For Parties': 5,
#  'Residential Buildings, Domestic Buildings': 5,
#  'Age Groups: Adolescents': 5,
#  'Farm & Working Animals': 5,
#  'Macintosh': 5,
#  'Prisons': 5,
#  'Fiction Books': 5,
#  'Geometry': 5,
#  'Clinical & Internal Medicine': 5,
#  'Church History': 5,
#  'Law For The Lay Person': 5,
#  'Rug & Carpetmaking': 5,
#  'Celebrity Chefs': 5,
#  'Hispanic & Latino Studies': 5,
#  'Business Applications': 5,
#  'Equestrian & Animal Sports': 5,
#  'Grammar, Syntax': 5,
#  'Discrete Mathematics': 5,
#  'Hoaxes & Deceptions': 4,
#  'Biochemical Engineering': 4,
#  'Protestantism & Protestant Churches': 4,
#  'Cinema Industry': 4,
#  'Elections & Referenda': 4,
#  'Retail Sector': 4,
#  'Oncology': 4,
#  'Philosophy Of Language': 4,
#  'Sociology: Sexual Relations': 4,
#  'Business, Finance & Law': 4,
#  'Forensic Science': 4,
#  'Keyboard Instruments': 4,
#  'Banking': 4,
#  'Atomic & Molecular Physics': 4,
#  'Food & Beverage Technology': 4,
#  'Blasphemy, Heresy, Apostasy': 4,
#  'Circus': 4,
#  'Social Impact Of Environmental Issues': 4,
#  'Age Groups: The Elderly': 4,
#  'Restaurant, Cafe & Pub Guides': 4,
#  'Railway Transport Industries': 4,
#  'Limnology (freshwater)': 4,
#  'Data Encryption': 4,
#  "Children's Geography Books": 4,
#  'Stocks & Shares': 4,
#  'Business Studies': 4,
#  'ELT Non-book Material & Resources': 4,
#  'Theosophy & Anthroposophy': 4,
#  'Publishing Industry': 4,
#  'Individual Photographers': 4,
#  'Memory Improvement & Thinking Techniques': 4,
#  'Nanotechnology': 4,
#  'Bibliographies, Catalogues, Discographies': 4,
#  'Fiction Companions': 4,
#  'Bullying & Anti-bullying Strategies': 4,
#  'Medical Ethics & Professional Conduct': 4,
#  'Electronic & Video Art': 4,
#  'Communications Engineering / Telecommunications': 4,
#  'Christian Liturgy, Prayerbooks & Hymnals': 4,
#  'Nuclear Weapons': 4,
#  'Human Figures Depicted In Art': 4,
#  'Architectural Structure & Design': 4,
#  'Christian Churches & Denominations': 4,
#  'Christian & Quasi-Christian Cults & Sects': 4,
#  'Hotel & Catering Trades': 4,
#  'Criticism & Exegesis Of Sacred Texts': 4,
#  'Coping With Eating Disorders': 4,
#  'Romantic Music (c 1830 To C 1900)': 4,
#  'Organic Farming': 4,
#  'Universities': 4,
#  'Fiction-related Items': 4,
#  'Early Church': 4,
#  'Christian Sermons': 4,
#  'Sports Psychology': 4,
#  'Military Veterans': 4,
#  'Gardening: Herbs': 4,
#  'Interdisciplinary Studies': 4,
#  'New Testaments': 4,
#  'Theatre: Technical & Background Skills': 4,
#  'Game Theory': 4,
#  'ELT: Teaching Theory & Methods': 4,
#  'Cooking With Herbs & Spices': 4,
#  'Animals & Nature In Art (still Life, Landscapes & Seascapes, Etc)': 4,
#  'Applied Physics': 4,
#  'Air Sports & Recreations': 4,
#  'Language: History & General Works': 4,
#  'Zoos & Wildlife Parks': 4,
#  'Caravan & Camp-site Guides': 4,
#  'Parapsychological Studies': 4,
#  'Textile Design & Theory': 4,
#  'Educational Equipment & Technology, Computer-aided Learning (CAL)': 4,
#  'Motor Sports': 4,
#  'Decorative Arts': 4,
#  'International Business': 4,
#  'Environmentalist Thought & Ideology': 4,
#  'Circuits & Components': 4,
#  'Macintosh OS': 4,
#  'Marine Engineering': 4,
#  'Enterprise Software': 4,
#  'Housing & Property For The Individual - Buying/selling & Legal Aspects': 4,
#  'Antiques & Collectables: Jewellery': 4,
#  'Handicrafts': 4,
#  'Arid Zones, Deserts': 4,
#  'Adoption': 4,
#  "Children's Foreign Language Dictionaries": 4,
#  'Blues': 4,
#  ...}

# %% [markdown]
# ## Smaller Dataset

# %%
num_ratings = df.groupby('isbn')['provided_rating'].count().sort_values(ascending=False)
most_rated_books = num_ratings.index[:10]
num_ratings = df.groupby('isbn')['provided_rating'].count().sort_values(ascending=False)
most_rated_books = num_ratings.index[:10]
num_ratings.head()
# Out:
# isbn
# 0316666343    707
# 0060928336    320
# 0671027360    269
# 067976402X    256
# 0786868716    242
# Name: provided_rating, dtype: int64

# %%
df.groupby('user_id')['provided_rating'].count().sort_values(ascending=False)
# Out:
# user_id
# 11676     1593
# 98391      595
# 189835     371
# 76499      333
# 153662     322
#           ...
# 59675        1
# 157184       1
# 59685        1
# 59697        1
# 278854       1
# Name: provided_rating, Length: 31940, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('isbn')['provided_rating'].mean())
ratings['num_ratings'] = pd.DataFrame(df.groupby('isbn')['provided_rating'].count())
ratings.head()
# Out:
#             provided_rating  num_ratings
# isbn
# 0002163578              5.0            1
# 0002190915              9.5            2
# 0002210479              6.0            1
# 0002222469              8.0            1
# 0002241358              8.0            1

# %%
min_ratings = 5
books_ = ratings.query(f"num_ratings > {min_ratings}").index
print(f"Number of books_ with more than {min_ratings} ratings: {len(books_)}")
print(f"Original number of books_: {df['isbn'].nunique()}")
print(f"Number of rows in the original dataset: {df.shape[0]}")
df_small = df[df['isbn'].isin(books_)]
unique_users = df_small['user_id'].nunique()
print(f"Number of rows in the new dataset: {df_small.shape[0]}")
print(f"Number of unique users in the new dataset: {unique_users}")
# Out:
# Number of books_ with more than 5 ratings: 3823
# Original number of books_: 22020
# Number of rows in the original dataset: 104756
# Number of rows in the new dataset: 72190
# Number of unique users in the new dataset: 25812

# %% [markdown]
# ## Preprocessing

# %%
n_users = df_small.user_id.nunique()
n_items = df_small.isbn.nunique()

print('Num. of Users: '+ str(n_users))
print('Num of Movies: '+str(n_items))
# Out:
# Num. of Users: 25812
# Num of Movies: 3823

# %%
user_id_map = dict(zip(df_small.user_id.unique(), list(range(n_users))))
book_id_map = dict(zip(df_small.isbn.unique(), list(range(n_items))))
user_id_map_df  = pd.DataFrame(
    {
        "user_id":user_id_map.keys(),
        "user_id_new": user_id_map.values(),
    }
)
book_id_map_df  = pd.DataFrame(
    {
        "isbn":book_id_map.keys(),
        "isbn_new": book_id_map.values(),
    }
)
df_small["user_id"] = df_small["user_id"].map(user_id_map)
df_small["isbn"] = df_small["isbn"].map(book_id_map)

# %%
df_small.head()
# Out:
#    user_id  isbn  provided_rating
# 0        0     0                6
# 1        0     1                5
# 2        1     2                9
# 3        2     3                7
# 4        3     4                8

# %%
def split_dataframe(df, holdout_fraction=0.1):
  """Splits a DataFrame into training and test sets.
  Args:
    df: a dataframe.
    holdout_fraction: fraction of dataframe rows to use in the test set.
  Returns:
    train: dataframe for training
    test: dataframe for testing
  """
  test = df.sample(frac=holdout_fraction, replace=False)
  train = df[~df.index.isin(test.index)]
  return train, test

train_df_, test_df_ = split_dataframe(df_small)

# %% [markdown]
# # Theory

# %% [markdown]
# Using neural networks instead of matrix factorization (MF) for recommendation systems has a number of advantages. See the notes section for detail. Here, we will be providing the model architecture that will be used for the recommendation system.

# %% [markdown]
# The model will consist of two steps:

# %% [markdown]
# ## The Embedding Layer

# %% [markdown]
# This layer will take the user and item IDs in one-hot encoded form along with any other user and item feature and will pass it through a fully connected layer. The output of this layer will be the latent representation of the user and item. Let use denote $\mathbf{u}$ as the user and $\mathbf{v}$ as the item. Their dimensions will be $m+m_{uf}$ and $n+n_{if}$ respectively where $m$ and $n$ are the number of users and items and $m_{uf}$ and $n_{if}$ are the number of user and item features respectively. The output of the embedding layer will be $\mathbf{u} \in \mathbb{R}^d$ and $\mathbf{v} \in \mathbb{R}^d$ where $d$ is the dimension of the latent space.

# %% [markdown]
# We will have two different layers, one for users and the other of items. This is required because the number of users and items are different and we want to learn different embeddings for them. The user embedding layer will have $m+m_{uf}$ neurons and the item embedding layer will have $n+n_{if}$ neurons.

# %% [markdown]
# ## CF Layers

# %% [markdown]
# CF layers, or collaborative filtering layers are made up of one or more layers of fully connected layers. The input to these layers will be the concatenation of the user and item latent representations. The output of the CF layers will be the predicted rating.
#
# ![](images/dl_01.png)

# %% [markdown]
# ## Loss Function

# %% [markdown]
# The loss function can either be MSE or cross entropy. We will be experimenting with both.

# %% [markdown]
# ## Data

# %% [markdown]
# We will be using all the positive data and a random sample of the negative data. The ratio of positive to negative data will be decided by a parameter.

# %% [markdown]
# # Model

# %%
train_df_.head()
# Out:
#    user_id  isbn  provided_rating
# 0        0     0                6
# 1        0     1                5
# 2        1     2                9
# 3        2     3                7
# 4        3     4                8
